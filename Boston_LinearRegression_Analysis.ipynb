# %% [markdown]
# <a href="https://colab.research.google.com/github/arlokesh/ML/blob/main/Boston_LinearRegression_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# /content

# %%
# !pip install PyDrive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':"1x5uAmxwLzllHxA6MG8HLYnvBlgJVYHhp"})   # replace the id with id of file you want to access
downloaded.GetContentFile('bostonhousing.csv')        # replace the file name with your file

# %%
import pandas as pd
df=pd.read_csv("bostonhousing.csv")

# %%
df
# Out:
#         crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0    0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93     0  0.573  ...  273     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93     0  0.573  ...  273     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93     0  0.573  ...  273     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93     0  0.573  ...  273     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93     0  0.573  ...  273     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.describe()
# Out:
#              crim          zn       indus  ...           b       lstat        medv
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677082   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
import seaborn as sns
X=df.iloc[:,:13]
Y=df.iloc[:,-1]
print(X.head())
print(Y.head())

sns.pairplot(df,hue ='medv',diag_kind = "kde",kind = "scatter",palette = "husl")
# Out:
#       crim    zn  indus  chas    nox  ...  rad  tax  ptratio       b  lstat
# 0  0.00632  18.0   2.31     0  0.538  ...    1  296     15.3  396.90   4.98
# 1  0.02731   0.0   7.07     0  0.469  ...    2  242     17.8  396.90   9.14
# 2  0.02729   0.0   7.07     0  0.469  ...    2  242     17.8  392.83   4.03
# 3  0.03237   0.0   2.18     0  0.458  ...    3  222     18.7  394.63   2.94
# 4  0.06905   0.0   2.18     0  0.458  ...    3  222     18.7  396.90   5.33
#
# [5 rows x 13 columns]
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: medv, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df.corr().round(2)
# Out:
#          crim    zn  indus  chas   nox  ...   tax  ptratio     b  lstat  medv
# crim     1.00 -0.20   0.41 -0.06  0.42  ...  0.58     0.29 -0.39   0.46 -0.39
# zn      -0.20  1.00  -0.53 -0.04 -0.52  ... -0.31    -0.39  0.18  -0.41  0.36
# indus    0.41 -0.53   1.00  0.06  0.76  ...  0.72     0.38 -0.36   0.60 -0.48
# chas    -0.06 -0.04   0.06  1.00  0.09  ... -0.04    -0.12  0.05  -0.05  0.18
# nox      0.42 -0.52   0.76  0.09  1.00  ...  0.67     0.19 -0.38   0.59 -0.43
# rm      -0.22  0.31  -0.39  0.09 -0.30  ... -0.29    -0.36  0.13  -0.61  0.70
# age      0.35 -0.57   0.64  0.09  0.73  ...  0.51     0.26 -0.27   0.60 -0.38
# dis     -0.38  0.66  -0.71 -0.10 -0.77  ... -0.53    -0.23  0.29  -0.50  0.25
# rad      0.63 -0.31   0.60 -0.01  0.61  ...  0.91     0.46 -0.44   0.49 -0.38
# tax      0.58 -0.31   0.72 -0.04  0.67  ...  1.00     0.46 -0.44   0.54 -0.47
# ptratio  0.29 -0.39   0.38 -0.12  0.19  ...  0.46     1.00 -0.18   0.37 -0.51
# ...

# %%
import seaborn as sns
df1=pd.DataFrame(df[['lstat','rm','medv']])
#Y=df.iloc[:,-1]
#print(X.head())
#print(Y.head())

sns.pairplot(df1,hue ='medv',diag_kind = "kde",kind = "scatter",palette = "husl")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))  
sns.heatmap(data=df.corr().round(2),annot=True)

# %%
corelation_matrix=df.corr().round(2)
features=corelation_matrix['medv']
features=features[(abs(features)> 0.6)]
print(features)
# Out:
# rm       0.70
# lstat   -0.74
# medv     1.00
# Name: medv, dtype: float64

# %%
df[['rm','lstat']]
# Out:
#         rm  lstat
# 0    6.575   4.98
# 1    6.421   9.14
# 2    7.185   4.03
# 3    6.998   2.94
# 4    7.147   5.33
# ..     ...    ...
# 501  6.593   9.67
# 502  6.120   9.08
# 503  6.976   5.64
# 504  6.794   6.48
# 505  6.030   7.88
#
# [506 rows x 2 columns]

# %%
y=df['medv']
x=df[['lstat','rm']]

# %%
x.shape
# Out:
# (506, 2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.6,random_state=5)

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.coef_)
print(lm.intercept_)
# Out:
# [-0.61363893  5.06281625]
# -1.211365240895045

# %%
output=5.06*6.3-1.211
print(output)

y=pd.DataFrame({'lstat':[12.8],'rm':[6.3]})
output_pred=lm.predict(y)
print(output_pred)
# Out:
# 30.666999999999998
# [22.82979883]

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

y_train_predict=lm.predict(x_train)
rmse=np.sqrt(mean_squared_error(y_train,y_train_predict))
r2=r2_score(y_train,y_train_predict)
print("rmse for X_train {}".format(rmse))
print("r2 for x_train {}".format(r2))
# Out:
# rmse 5.625503677650756
# r2 0.6402079006992452

# %%
y_test_predict=lm.predict(x_test)
rmse=np.sqrt(mean_squared_error(y_test,y_test_predict))
r2=r2_score(y_test,y_test_predict)
print("rmse for Y_pred {}".format(rmse))
print("r2 score for y_pred {}".format(r2))
# Out:
# rmse for Y_pred 5.477086723468159
# r2 score for y_pred 0.634440490735495
